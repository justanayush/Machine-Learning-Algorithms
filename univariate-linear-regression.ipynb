# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn import linear_model

# %%
df = pd.read_csv('canada_per_capita_income.csv')

# %%
df.head()
# Out:
#    year  per capita income (US$)
# 0  1970              3399.299037
# 1  1971              3768.297935
# 2  1972              4251.175484
# 3  1973              4804.463248
# 4  1974              5576.514583

# %%
reg = linear_model.LinearRegression()
reg.fit(df[['year']], df[['per capita income (US$)']])
# Out:
# LinearRegression()

# %%
reg.predict([[1987]])
# Out:
# C:\Users\freak\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[13949.34661207]])

# %%
reg.coef_
# Out:
# array([[828.46507522]])

# %%
reg.intercept_
# Out:
# array([-1632210.75785546])

# %%
828.46507522 * 1987 -1632210.75785546
# Out:
# 13949.34660667996

# %%
plt.xlabel('year')
plt.ylabel('per capita income(USD)')
plt.scatter(df.year, df['per capita income (US$)'], color='red', marker='+')
y = reg.predict(df[['year']])
plt.plot(df[['year']], y, color='blue')
